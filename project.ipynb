# %% [markdown]
# file downloading

# %%
import ee
import folium
from glob import glob
import geopandas as gpd
import pandas as pd
ee.Initialize()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import ee
#       2 import folium
#       3 from glob import glob
#
# ModuleNotFoundError: No module named 'ee'

# %%
# Initialize the Earth Engine API




ee.Initialize()

# Define a method to display Earth Engine image tiles on a folium map.
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Map Data &copy; Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)

# Add Earth Engine drawing method to folium.
folium.Map.add_ee_layer = add_ee_layer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       1 # Initialize the Earth Engine API
# ----> 6 ee.Initialize()
#       8 # Define a method to display Earth Engine image tiles on a folium map.
#       9 def add_ee_layer(self, ee_image_object, vis_params, name):
#
# NameError: name 'ee' is not defined

# %%
gdf= gpd.read_file('/Users/skaryang/Desktop/vs/python/DATA IN GEOPACKAGE FORMAT 2/LAKE_OUTLINES/PANGONG_LAKE_1994.gpkg')
gdf.head()
# Out:
#       CenLon     CenLat  Zmean        Area  U_Area  \
# 0  78.738871  33.699022   4241  619.239807    7.16
#
#                                             geometry
# 0  MULTIPOLYGON (((943254.056 3714448.700, 943143...

# %%
gdf.shape
# Out:
# (1, 6)

# %%
gdf['area'] = gdf.area

# %%
gdf = gdf.to_crs(epsg=4326)
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
gdf.plot('area')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 gdf.plot('area')
#
# NameError: name 'gdf' is not defined

# %%
gdf1 = gpd.read_file('DATA IN GEOPACKAGE FORMAT 2/GLACIER_OUTLINES/SHAYOK_GLACIERS_2019.gpkg')
gdf1.head()
# Out:
#   JNUOAId           RGIId         GLIMSId     CenLon     CenLat  Zmax  Zmean  \
# 0     SH1  RGI60-14.05890  G077428E35296N  77.426422  35.441423  6735   5682
# 1     SH2  RGI60-14.05890  G077428E35296N  77.466888  35.326932  7185   5636
# 2     SH3  RGI60-14.07524  G076894E35428N  77.127898  35.284234  5975   5476
# 3     SH4  RGI60-14.05890  G077428E35296N  77.345828  35.303098  6846   5485
# 4     SH5  RGI60-14.07779  G077294E35212N  77.300144  35.213109  5991   5462
#
#    Zmin  MeanAspect  MeanSlope        Area       Lmax    U_Area    U_Lmax  \
# 0  4993          94        8.0  213.658653  42.013713  1.187118  0.630206
# 1  4970          66       12.0  155.586575  23.154289  1.136624  0.347314
# 2  5155         179       19.0    0.853255   2.367143  0.028256  0.035507
# 3  3975         216       16.0   89.474485  20.862702  1.062182  0.312941
# 4  4618          33       18.0    4.766370   5.714494  0.080365  0.085717
#
#                                             geometry
# ...

# %%
gdf1.shape
# Out:
# (1262, 15)

# %%
gdf1['area']= gdf1.area
gdf1 = gdf1.to_crs(epsg=4326)
gdf1.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
gdf1.plot('area')
# Out:
# <Axes: >
